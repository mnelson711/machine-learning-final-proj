# %%
#Employee performace Prediction

# %%
#importing the dataset
import pandas as pd
import sklearn as sk
# %matplotlib inline

data = pd.read_csv('data.csv')

#showing first five rows of data
data.head(5)
len(data)
# Out:
# 1017

# %%
#linear regression model

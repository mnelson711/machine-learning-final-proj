# %%
#Employee performace Prediction
#johana test line

# %%
#this is a test

# %%
#importing the dataset
import pandas as pd
import sklearn as sk
# %matplotlib inline

data = pd.read_csv('data.csv')

#showing first five rows of data
data.head(10)
len(data)
# Out:
# 1017

# %%
#linear regression model
#here we will test out a linear regression model

# %%
#importing the dataset
import pandas as pd
import math
# %matplotlib inline

data = pd.read_csv('transformed_data.csv')

data.head(5)
# Out:
#    team  targeted_productivity    smv    wip  over_time  incentive  idle_time  \
# 0     9                   0.75   3.94    0.0        960          0        0.0
# 1     7                   0.65  30.10  909.0       7080          0        0.0
# 2     3                   0.80   4.15    0.0       1440          0        0.0
# 3     1                   0.65  22.53  762.0       5040          0        0.0
# 4     4                   0.70  30.10  767.0       3300         50        0.0
#
#    idle_men  no_of_style_change  no_of_workers  department_finishing   \
# 0         0                   0              8                      0
# 1         0                   1             59                      0
# 2         0                   0              7                      1
# 3         0                   1             42                      0
# 4         0                   1             57                      0
#
#    actual_productivity        day  quarter_num department  idle_time?  \
# 0             0.755167  Wednesday            1  finishing       False
# 1             0.535678   Thursday            2     sweing       False
# 2             0.820833  Wednesday            2  finishing       False
# 3             0.581131  Wednesday            4     sweing       False
# 4             0.790003     Monday            2     sweing       False
#
#    idle_men?
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
#transforming the day column - from a String to an Int

def day_column():
    day = []
    for index, row in data.iterrows():
        if(row['day'] == "Monday"):
            day.append(1)
        elif (row['day'] == "Tuesday"):
            day.append(2)
        elif (row['day'] == "Wednesday"):
            day.append(3)
        elif (row['day'] == "Thursday"):
            day.append(4)
        elif (row['day'] == "Saturday"):
            day.append(6)
        elif (row['day'] == "Sunday"):
            day.append(7)
    data["day"] = day

day_column()
data.head(5)
# Out:
#    team  targeted_productivity    smv    wip  over_time  incentive  idle_time  \
# 0     9                   0.75   3.94    0.0        960          0        0.0
# 1     7                   0.65  30.10  909.0       7080          0        0.0
# 2     3                   0.80   4.15    0.0       1440          0        0.0
# 3     1                   0.65  22.53  762.0       5040          0        0.0
# 4     4                   0.70  30.10  767.0       3300         50        0.0
#
#    idle_men  no_of_style_change  no_of_workers  department_finishing   \
# 0         0                   0              8                      0
# 1         0                   1             59                      0
# 2         0                   0              7                      1
# 3         0                   1             42                      0
# 4         0                   1             57                      0
#
#    actual_productivity  day  quarter_num department  idle_time?  idle_men?
# 0             0.755167    3            1  finishing       False      False
# 1             0.535678    4            2     sweing       False      False
# 2             0.820833    3            2  finishing       False      False
# 3             0.581131    3            4     sweing       False      False
# 4             0.790003    1            2     sweing       False      False

# %%
#transforming the department column - from a String to an Int

def department_column():
    department = []
    for index, row in data.iterrows():
        if(row['department'] == "finishing"):
            department.append(1)
        elif (row['department'] == "sweing"):
            department.append(2)

    data["department"] = department

department_column()
data.head(5)
# Out:
#    team  targeted_productivity    smv    wip  over_time  incentive  idle_time  \
# 0     9                   0.75   3.94    0.0        960          0        0.0
# 1     7                   0.65  30.10  909.0       7080          0        0.0
# 2     3                   0.80   4.15    0.0       1440          0        0.0
# 3     1                   0.65  22.53  762.0       5040          0        0.0
# 4     4                   0.70  30.10  767.0       3300         50        0.0
#
#    idle_men  no_of_style_change  no_of_workers  department_finishing   \
# 0         0                   0              8                      0
# 1         0                   1             59                      0
# 2         0                   0              7                      1
# 3         0                   1             42                      0
# 4         0                   1             57                      0
#
#    actual_productivity  day  quarter_num  department  idle_time?  idle_men?
# 0             0.755167    3            1           1       False      False
# 1             0.535678    4            2           2       False      False
# 2             0.820833    3            2           1       False      False
# 3             0.581131    3            4           2       False      False
# 4             0.790003    1            2           2       False      False

# %%
#transforming the idle_time? column - from True/False to 1/0

def idle_time_column():
    time = []
    for index, row in data.iterrows():
        if(row['idle_time?'] == False):
            time.append(0)
        elif (row['idle_time?'] == True):
            time.append(1)

    data["idle_time?"] = time

idle_time_column()
data.head(5)
# Out:
#    team  targeted_productivity    smv    wip  over_time  incentive  idle_time  \
# 0     9                   0.75   3.94    0.0        960          0        0.0
# 1     7                   0.65  30.10  909.0       7080          0        0.0
# 2     3                   0.80   4.15    0.0       1440          0        0.0
# 3     1                   0.65  22.53  762.0       5040          0        0.0
# 4     4                   0.70  30.10  767.0       3300         50        0.0
#
#    idle_men  no_of_style_change  no_of_workers  department_finishing   \
# 0         0                   0              8                      0
# 1         0                   1             59                      0
# 2         0                   0              7                      1
# 3         0                   1             42                      0
# 4         0                   1             57                      0
#
#    actual_productivity  day  quarter_num  department  idle_time?  idle_men?
# 0             0.755167    3            1           1           0      False
# 1             0.535678    4            2           2           0      False
# 2             0.820833    3            2           1           0      False
# 3             0.581131    3            4           2           0      False
# 4             0.790003    1            2           2           0      False

# %%
#transforming the idle_men? column - from True/False to 1/0

def idle_men_column():
    men = []
    for index, row in data.iterrows():
        if(row['idle_men?'] == False):
            men.append(0)
        elif (row['idle_men?'] == True):
            men.append(1)

    data["idle_men?"] = men

idle_men_column()
data.head(5)
# Out:
#    team  targeted_productivity    smv    wip  over_time  incentive  idle_time  \
# 0     9                   0.75   3.94    0.0        960          0        0.0
# 1     7                   0.65  30.10  909.0       7080          0        0.0
# 2     3                   0.80   4.15    0.0       1440          0        0.0
# 3     1                   0.65  22.53  762.0       5040          0        0.0
# 4     4                   0.70  30.10  767.0       3300         50        0.0
#
#    idle_men  no_of_style_change  no_of_workers  department_finishing   \
# 0         0                   0              8                      0
# 1         0                   1             59                      0
# 2         0                   0              7                      1
# 3         0                   1             42                      0
# 4         0                   1             57                      0
#
#    actual_productivity  day  quarter_num  department  idle_time?  idle_men?
# 0             0.755167    3            1           1           0          0
# 1             0.535678    4            2           2           0          0
# 2             0.820833    3            2           1           0          0
# 3             0.581131    3            4           2           0          0
# 4             0.790003    1            2           2           0          0

# %%
#import statements

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn import tree
import matplotlib.pyplot as plt

# %%
#X holds the features of the model

X = pd.concat((data.iloc[:, 0:11], data.iloc[:, 12:]), axis=1)
X.head(5)
# Out:
#    team  targeted_productivity    smv    wip  over_time  incentive  idle_time  \
# 0     9                   0.75   3.94    0.0        960          0        0.0
# 1     7                   0.65  30.10  909.0       7080          0        0.0
# 2     3                   0.80   4.15    0.0       1440          0        0.0
# 3     1                   0.65  22.53  762.0       5040          0        0.0
# 4     4                   0.70  30.10  767.0       3300         50        0.0
#
#    idle_men  no_of_style_change  no_of_workers  department_finishing   day  \
# 0         0                   0              8                      0    3
# 1         0                   1             59                      0    4
# 2         0                   0              7                      1    3
# 3         0                   1             42                      0    3
# 4         0                   1             57                      0    1
#
#    quarter_num  department  idle_time?  idle_men?
# 0            1           1           0          0
# 1            2           2           0          0
# 2            2           1           0          0
# 3            4           2           0          0
# 4            2           2           0          0

# %%
#y holds the target

y = data[['actual_productivity']]
y.head(5)
# Out:
#    actual_productivity
# 0             0.755167
# 1             0.535678
# 2             0.820833
# 3             0.581131
# 4             0.790003

# %%
#splitting the data into 30% testing and 70% training

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
#fitting the Decision Tree Regression Model (the target variable is continuous)

rgr = tree.DecisionTreeRegressor(random_state=28)
rgr = rgr.fit(X_train, y_train)

# %%
#testing the model by calculating the mean squared error

y_pred = rgr.predict(X_test)

# RMSE (Root Mean Square Error)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("\nRMSE: ", rmse)
mse = mean_squared_error(y_test, y_pred)
print("\nMSE: ", mse)
r2 = r2_score(y_test, y_pred)
print("\nR2_Score ", r2)
# Out:
# RMSE:  0.171
#
# MSE:  0.02936904293521939
#
# R2_Score  0.05522929547311761

# %%
#graphing the tree

from sklearn.tree import export_graphviz  

export_graphviz(rgr, out_file ='tree_structure.dot', 
               feature_names =['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive', 'idle_time'
                               , 'idle_men', 'no_of_style_change', '	no_of_workers'
                               , 'department_finishing', 'day', 'quarter_num'
                               , 'department', 'idle_time?', 'idle_men?'])

# %%
#visualize decision tree
feat_names = ['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive', 'idle_time'
                               , 'idle_men', 'no_of_style_change', '	no_of_workers'
                               , 'department_finishing', 'day', 'quarter_num'
                               , 'department', 'idle_time?', 'idle_men?']

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(rgr, 
                   feature_names=feat_names,  
                   class_names='actual_productivity',
                   filled=True)
fig.savefig("decistion_tree.png")
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# c:\Users\Johana Papa\OneDrive\Desktop\Machine Learning\Final Project\machine-learning-final-proj\decisiontree.ipynb Cell 13 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> feat_names = ['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive', 'idle_time'
#       <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>                                , 'idle_men', 'no_of_style_change', '	no_of_workers'
#       <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>                                , 'department_finishing', 'day', 'quarter_num'
#       <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>                                , 'department', 'idle_time?', 'idle_men?']
#       <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> fig = plt.figure(figsize=(25,20))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> _ = tree.plot_tree(rgr,
#       <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>                    feature_names=feat_names,
#      <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>                    class_names='actual_productivity',
#      <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>                    filled=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/Johana%20Papa/OneDrive/Desktop/Machine%20Learning/Final%20Project/machine-learning-final-proj/decisiontree.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a> fig.savefig("decistion_tree.png")
#
# File c:\Users\Johana Papa\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:201, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     198 to_ignore += ["self", "cls"]
#     199 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 201 validate_parameter_constraints(
#     202     parameter_constraints, params, caller_name=func.__qualname__
#     203 )
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
#
# File c:\Users\Johana Papa\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'class_names' parameter of plot_tree must be an instance of 'list' or None. Got 'actual_productivity' instead.
